# %%
import sys
lib_path = '/home/jovyan/libs'
sys.path.insert(0, lib_path)

# %%
# %reload_ext autoreload
# %autoreload 2

import torch
import whisper

# %%
t = whisper.tokenizer.get_tokenizer(multilingual=False)

# %%
t
# Out:
# Tokenizer(encoding=<Encoding 'gpt2.tiktoken'>, num_languages=99, language=None, task=None, sot_sequence=(50257,), special_tokens={'<|10.72|>': 50899, '<|21.64|>': 51445, '<|1.14|>': 50420, '<|11.10|>': 50918, '<|14.96|>': 51111, '<|6.10|>': 50668, '<|13.64|>': 51045, '<|8.12|>': 50769, '<|18.18|>': 51272, '<|24.44|>': 51585, '<|6.86|>': 50706, '<|9.98|>': 50862, '<|4.80|>': 50603, '<|20.84|>': 51405, '<|oc|>': 50327, '<|15.32|>': 51129, '<|yo|>': 50324, '<|20.86|>': 51406, '<|1.66|>': 50446, '<|21.98|>': 51462, '<|21.94|>': 51460, '<|13.74|>': 51050, '<|15.36|>': 51131, '<|9.54|>': 50840, '<|24.04|>': 51565, '<|19.78|>': 51352, '<|13.20|>': 51023, '<|24.90|>': 51608, '<|7.68|>': 50747, '<|16.70|>': 51198, '<|29.62|>': 51844, '<|17.52|>': 51239, '<|17.08|>': 51217, '<|24.42|>': 51584, '<|1.90|>': 50458, '<|16.52|>': 51189, '<|mn|>': 50313, '<|20.30|>': 51378, '<|27.92|>': 51759, '<|12.00|>': 50963, '<|6.92|>': 50709, '<|25.94|>': 51660, '<|27.14|>': 51720, '<|1.60|>': 50443, '<|16.50|
# ...
